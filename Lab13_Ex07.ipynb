// %% [markdown]
// # Lab 13 Exercise 1

// %% [markdown]
// ## Polymorphism กับ Method Parameters

// %% [markdown]
// เมธอดสามารถรับพารามิเตอร์ที่เป็นชนิดของ base class ได้ และเมื่อมีการส่งวัตถุของ derived class เข้าไป  เมธอดนั้นจะสามารถทำงานกับวัตถุของ derived class ได้เช่นกัน
//
// เนื่องจาก derived class สืบทอดมาจาก base class เป็นผลให้วัตถุของ derived class มีคุณสมบัติและเมธอดของ base class ตามไปด้วย ทำให้สามารถส่งเข้าไปในเมธอดที่รับพารามิเตอร์เป็นชนิดของ base class ได้

// %% [markdown]
// 1.สร้าง console application project ชื่อ Lab09_Ex07

// %% [markdown]
// 2.เปลี่ยน code ให้เป็นดังต่อไปนี้
//
// ```csharp
// public abstract class Shape
// {
//     public abstract double Area();
//     public abstract void Draw();
// }
//
// public class Circle : Shape
// {
//     public double Radius { get; set; }
//
//     public Circle(double radius)
//     {
//         Radius = radius;
//     }
//
//     public override double Area()
//     {
//         return Math.PI * Radius * Radius;
//     }
//
//     public override void Draw()
//     {
//         Console.WriteLine($"Drawing a circle with radius {Radius}");
//     }
// }
//
// public class Rectangle : Shape
// {
//     public double Width { get; set; }
//     public double Height { get; set; }
//
//     public Rectangle(double width, double height)
//     {
//         Width = width;
//         Height = height;
//     }
//
//     public override double Area()
//     {
//         return Width * Height;
//     }
//
//     public override void Draw()
//     {
//         Console.WriteLine($"Drawing a rectangle with width {Width} and height {Height}");
//     }
// }
//
// public class ShapeProcessor
// {
//     public void DisplayShapeInfo(Shape shape)
//     {
//         Console.WriteLine($"Area of {shape.GetType().Name}: {shape.Area()}");
//         shape.Draw();
//     }
// }
//
//
// ShapeProcessor processor = new ShapeProcessor();
//
// Circle circle = new Circle(5);
// processor.DisplayShapeInfo(circle);
//
// Rectangle rectangle = new Rectangle(4, 6);
// processor.DisplayShapeInfo(rectangle);
// ```

// %% [markdown]
// 3.Build project โดยการใช้คำสั่ง
//
// ```cmd
// dotnet build  Lab13_Ex03
// ```
//
// ถ้ามีที่ผิดพลาดในโปรแกรม ให้แก้ไขให้ถูกต้อง

// %% [markdown]
// 4.บันทึกผลที่ได้จากการรันคำสั่งในข้อ 3

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 5.Run project โดยการใช้คำสั่ง
//
// ```cmd
// dotnet run --project Lab13_Ex03
// ```

// %% [markdown]
// 6.บันทึกผลที่ได้จากการรันคำสั่งในข้อ 5

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 7.อธิบายสิ่งที่พบในการทดลอง (การส่ง object ของ derived class เป็น parameter ของ method ที่รับใน base class)

// %% [markdown]
// Polymorphism:
//
// สามารถส่งอ็อบเจ็กต์ของ Derived Class (เช่น Circle หรือ Rectangle) เป็นพารามิเตอร์ของเมธอดใน Base Class (เช่น Shape) ได้
//
// ทำให้โค้ดสามารถจัดการกับอ็อบเจ็กต์หลายประเภทได้ภายใต้คลาสแม่เดียวกัน
//
// การ Override:
//
// เมธอด Area() และ Draw() ใน Derived Class ถูก override เพื่อให้มีพฤติกรรมเฉพาะตามชนิดของรูปทรง
//
// เมธอดใน Derived Class จะถูกเรียกใช้เมื่อส่งอ็อบเจ็กต์ของคลาสลูกเข้ามาในเมธอดของคลาสแม่
//
// การทำงาน:
//
// เมื่อส่งอ็อบเจ็กต์ Circle หรือ Rectangle ไปยังเมธอด DisplayShapeInfo() ของ ShapeProcessor ระบบจะเรียกเมธอดที่ถูก override ตามประเภทจริงของอ็อบเจ็กต์
//
// ตัวอย่างเช่น เมื่อเรียก processor.DisplayShapeInfo(circle); จะเรียก circle.Draw() และ circle.Area()
